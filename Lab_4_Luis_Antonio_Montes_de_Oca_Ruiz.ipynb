# %%
import folium
from folium.plugins import minimap

my_map = folium.Map(location=(10.416429060340459, -83.95164053211337))

folium.Marker(location=[10.617697478449156, -85.4514941870827], popup='<b>Sede Liberia</b>', icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.617697478449156, -85.4514941870827], color="red", weight=6, fill_color="white", fill_opacity=0.5, tooltip="Guanacaste").add_to(my_map)

folium.Marker(location=[9.971118100656495, -84.12846647156772], popup='<b>Benjamin Nuñez</b>', icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[9.971118100656495, -84.12846647156772], color="red", weight=6, fill_color="white", fill_opacity=0.5, tooltip="Benjamin Nuñez").add_to(my_map)

folium.Marker(location=[9.998930912714219, -84.11149755064527], popup='<b>Sede central</b>', icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[9.998930912714219, -84.11149755064527], color="red", weight=6, fill_color="white", fill_opacity=0.5, tooltip="Sede Central").add_to(my_map)

folium.Marker(location=[10.019997929269435, -84.1969824104668], popup='<b>Sede Interuniversitaria</b>', icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.019997929269435, -84.1969824104668], color="red", weight=6, fill_color="white", fill_opacity=0.5, tooltip="Sede Interuniversitaria").add_to(my_map)

folium.Marker(location=[10.319245009823174, -83.92282217221833], popup='<b>Sede Sarapiquí</b>', icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.319245009823174, -83.92282217221833], color="red", weight=6, fill_color="white", fill_opacity=0.5, tooltip="Sede Sarapiquí").add_to(my_map)

folium.Marker(location=[8.573692970603725, -82.87242258694764], popup='<b>Sede Coto</b>', icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[8.573692970603725, -82.87242258694764], color="red", weight=6, fill_color="white", fill_opacity=0.5, tooltip="Sede Coto").add_to(my_map)

folium.Marker(location=[9.379871591030646, -83.69153593560458], popup='<b>Sede Perez Zeledón</b>', icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[9.379871591030646, -83.69153593560458], color="red", weight=6, fill_color="white", fill_opacity=0.5, tooltip="Sede Perez Zeledón").add_to(my_map)

folium.Marker(location=[10.13459177938412, -85.44660537466835], popup='<b>Sede Nicoya</b>', icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.13459177938412, -85.44660537466835], color="red", weight=6, fill_color="white", fill_opacity=0.5, tooltip="Sede Nicoya").add_to(my_map)

minimap = minimap.MiniMap(title_layer='statementerrain', position='bottomright')

my_map.add_child(minimap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
